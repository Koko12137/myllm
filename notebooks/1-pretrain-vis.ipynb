# %%
import os

# %%
os.getcwd()
# Out:
# '/workspace'

# %%
os.chdir('/workspace/koko/myllm')
os.getcwd()
# Out:
# '/workspace/koko/myllm'

# %%
import json

import matplotlib.pyplot as plt

# %% [markdown]
# # Load Train Logs

# %%
log_file = 'output/checkpoint-46000/trainer_state.json'
with open(log_file, 'r') as f:
    log = json.load(f)['log_history']
log[0]
# Out:
# {'epoch': 0.0014343600961021264,
#  'grad_norm': 6.8230085372924805,
#  'learning_rate': 0.00011800000000000002,
#  'loss': 8.5187,
#  'step': 20}

# %%
losses = [x['loss'] for x in log]
steps = [x['step'] for x in log]

# %% [markdown]
# # Plot loss

# %%
# Set up a figure and axis with a specific size
fig, ax = plt.subplots(figsize=(10, 6))

# Set title and labels
ax.set_title('Loss over Steps')
ax.set_xlabel('Steps')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
# Plot the data
ax.plot(steps, losses)

# %%
fig
